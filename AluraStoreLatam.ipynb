# %% [markdown]
# <a href="https://colab.research.google.com/github/yaramirezte/Python-para-Data-Science-Challenge-AluraStore/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url1 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda1 = pd.read_csv(url1)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda1.head()
tienda1.sample(5)
# Out:
#                        Producto Categoría del Producto    Precio  \
# 1071          Balón de voleibol   Deportes y diversión   48700.0
# 1827            Sofá reclinable                Muebles  695500.0
# 706         Modelado predictivo                 Libros   46900.0
# 892   Carrito de control remoto               Juguetes   88000.0
# 1435                  Impresora           Electrónicos  349400.0
#
#       Costo de envío Fecha de Compra         Vendedor Lugar de Compra  \
# 1071          3000.0      16/08/2021  Ángel Rodriguez         Pereira
# 1827         37200.0      27/05/2020  Ángel Rodriguez    Barranquilla
# 706           4900.0      19/05/2020  Beatriz Morales          Bogotá
# 892           2900.0      25/02/2023  Beatriz Morales          Bogotá
# 1435         16800.0      17/11/2021    Lucas Olivera            Cali
#
#       Calificación      Método de pago  Cantidad de cuotas       lat       lon
# 1071             5  Tarjeta de crédito                   1   4.81333 -75.69611
# 1827             4  Tarjeta de crédito                  10  10.96854 -74.78132
# 706              1  Tarjeta de crédito                   3   4.60971 -74.08175
# 892              5  Tarjeta de crédito                   2   4.60971 -74.08175
# 1435             5  Tarjeta de crédito                   1   3.43722 -76.52250

# %%
tienda1['Precio'].isnull().sum()
tienda1.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda1['Producto'].unique()
# Out:
# array(['Asistente virtual', 'Mesa de comedor', 'Juego de mesa',
#        'Microondas', 'Silla de oficina', 'Bloques de construcción',
#        'Muñeca bebé', 'Lavavajillas', 'Lavadora de ropa',
#        'Carrito de control remoto', 'Refrigerador', 'Auriculares',
#        'Olla de presión', 'Bicicleta', 'Ciencia de datos con Python',
#        'Balón de voleibol', 'Ajedrez de madera', 'TV LED UHD 4K',
#        'Vaso térmico', 'Kit de bancas', 'Dashboards con Power BI',
#        'Cubertería', 'Set de ollas', 'Batería', 'Cuerda para saltar',
#        'Estufa', 'Cama box', 'Impresora', 'Mesa de noche', 'Armario',
#        'Dinosaurio Rex', 'Guitarra eléctrica', 'Secadora de ropa',
#        'Sofá reclinable', 'Tablet ABXY', 'Cubo mágico 8x8',
#        'Set de vasos', 'Modelado predictivo', 'Iphone 15', 'Mochila',
#        'Balón de baloncesto', 'Auriculares con micrófono', 'Sillón',
#        'Guitarra acústica', 'Iniciando en programación', 'Celular ABXY',
#        'Smartwatch', 'Mesa de centro', 'Cama king', 'Smart TV',
#        'Pandereta'], dtype=object)

# %%
tienda1.shape
# Out:
# (2359, 12)

# %%
tienda1['Fecha de Compra'] = pd.to_datetime(tienda1['Fecha de Compra'], format='%d/%m/%Y')

# %%
tienda1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   datetime64[ns]
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.3+ KB

# %%
tienda1.describe()
# Out:
#              Precio  Costo de envío                Fecha de Compra  \
# count  2.359000e+03     2359.000000                           2359
# mean   4.878679e+05    26018.609580  2021-08-17 12:02:08.189911296
# min    7.600000e+03        0.000000            2020-01-01 00:00:00
# 25%    5.575000e+04     3100.000000            2020-10-26 00:00:00
# 50%    2.353000e+05    12400.000000            2021-08-23 00:00:00
# 75%    6.781000e+05    36000.000000            2022-06-06 00:00:00
# max    2.977000e+06   160800.000000            2023-03-31 00:00:00
# std    6.146868e+05    32860.001783                            NaN
#
#        Calificación  Cantidad de cuotas          lat          lon
# count   2359.000000         2359.000000  2359.000000  2359.000000
# mean       3.976685            2.943196     5.365283   -74.789417
# min        1.000000            1.000000    -4.215280   -77.281110
# 25%        3.000000            1.000000     4.609710   -75.563590
# 50%        5.000000            1.000000     4.609710   -74.199040
# 75%        5.000000            4.000000     6.251840   -74.081750
# max        5.000000           24.000000    11.544440   -67.923900
# std        1.415370            2.819897     2.287445     1.217827

# %%
tienda2.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda2.shape
# Out:
# (2359, 12)

# %%
tienda2['Fecha de Compra'] = pd.to_datetime(tienda2['Fecha de Compra'], format='%d/%m/%Y')

# %%
tienda2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   datetime64[ns]
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.3+ KB

# %%
tienda2.describe()
# Out:
#              Precio  Costo de envío                Fecha de Compra  \
# count  2.359000e+03     2359.000000                           2359
# mean   4.732274e+05    25216.235693  2021-08-23 05:49:09.894022912
# min    7.600000e+03        0.000000            2020-01-01 00:00:00
# 25%    5.455000e+04     2900.000000            2020-10-31 00:00:00
# 50%    2.182000e+05    11600.000000            2021-08-27 00:00:00
# 75%    6.777000e+05    35450.000000            2022-06-10 00:00:00
# max    2.953400e+06   162500.000000            2023-03-31 00:00:00
# std    5.955595e+05    31741.375166                            NaN
#
#        Calificación  Cantidad de cuotas          lat          lon
# count   2359.000000         2359.000000  2359.000000  2359.000000
# mean       4.037304            2.902501     5.499753   -74.742963
# min        1.000000            1.000000    -4.215280   -77.281110
# 25%        4.000000            1.000000     4.609710   -75.563590
# 50%        5.000000            1.000000     4.609710   -74.199040
# 75%        5.000000            4.000000     6.251840   -74.081750
# max        5.000000           24.000000    11.544440   -67.923900
# std        1.356153            2.848416     2.351118     1.185997

# %%
tienda3.shape
# Out:
# (2359, 12)

# %%
tienda3.isnull().sum()
# Out:
# Producto                  0
# Categoría del Producto    0
# Precio                    0
# Costo de envío            0
# Fecha de Compra           0
# Vendedor                  0
# Lugar de Compra           0
# Calificación              0
# Método de pago            0
# Cantidad de cuotas        0
# lat                       0
# lon                       0
# dtype: int64

# %%
tienda3['Fecha de Compra'] = pd.to_datetime(tienda3['Fecha de Compra'], format='%d/%m/%Y')

# %%
tienda3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   datetime64[ns]
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(5)
# memory usage: 221.3+ KB

# %%
tienda3.describe()
# Out:
#              Precio  Costo de envío                Fecha de Compra  \
# count  2.359000e+03     2359.000000                           2359
# mean   4.654598e+05    24805.680373  2021-08-22 16:01:25.459940608
# min    7.600000e+03        0.000000            2020-01-01 00:00:00
# 25%    5.740000e+04     3100.000000            2020-10-27 12:00:00
# 50%    2.263000e+05    11900.000000            2021-09-06 00:00:00
# 75%    6.660500e+05    34950.000000            2022-06-15 12:00:00
# max    2.968200e+06   158400.000000            2023-03-31 00:00:00
# std    5.806434e+05    30945.889626                            NaN
#
#        Calificación  Cantidad de cuotas          lat          lon
# count   2359.000000         2359.000000  2359.000000  2359.000000
# mean       4.048326            2.967783     5.437076   -74.733463
# min        1.000000            1.000000    -4.215280   -77.281110
# 25%        4.000000            1.000000     4.609710   -75.563590
# 50%        5.000000            2.000000     4.609710   -74.199040
# 75%        5.000000            4.000000     6.251840   -74.081750
# max        5.000000           24.000000    11.544440   -67.923900
# std        1.386426            2.812153     2.405272     1.224572

# %%
tienda4['Fecha de Compra'] = pd.to_datetime(tienda4['Fecha de Compra'], format='%d/%m/%Y')

# %%
set(tienda1.columns) == set(tienda2.columns) == set(tienda3.columns)== set(tienda4.columns)
# Out:
# True

# %%
todas = set(tienda1.columns) | set(tienda2.columns) | set(tienda3.columns) | set(tienda4.columns)
comunes = set(tienda1.columns) & set(tienda2.columns) & set(tienda3.columns) & set(tienda4.columns)
diferencias = todas - comunes

diferencias
# tienen exactamente las mismas columnas
# Out:
# set()

# %%
# Nombres de columnas y tipos de datos de cada columna  por tienda
for i, df in enumerate([tienda1, tienda2, tienda3, tienda4], start=1):
    print(f"DataFrame tienda{i}")
    print(df.dtypes)
    print("-" * 40)
# Out:
# DataFrame tienda1
# Producto                          object
# Categoría del Producto            object
# Precio                           float64
# Costo de envío                   float64
# Fecha de Compra           datetime64[ns]
# Vendedor                          object
# Lugar de Compra                   object
# Calificación                       int64
# Método de pago                    object
# Cantidad de cuotas                 int64
# lat                              float64
# lon                              float64
# dtype: object
# ----------------------------------------
# DataFrame tienda2
# Producto                          object
# Categoría del Producto            object
# Precio                           float64
# Costo de envío                   float64
# Fecha de Compra           datetime64[ns]
# Vendedor                          object
# Lugar de Compra                   object
# Calificación                       int64
# Método de pago                    object
# Cantidad de cuotas                 int64
# lat                              float64
# lon                              float64
# dtype: object
# ----------------------------------------
# DataFrame tienda3
# Producto                          object
# Categoría del Producto            object
# Precio                           float64
# Costo de envío                   float64
# Fecha de Compra           datetime64[ns]
# Vendedor                          object
# Lugar de Compra                   object
# Calificación                       int64
# Método de pago                    object
# Cantidad de cuotas                 int64
# lat                              float64
# lon                              float64
# dtype: object
# ----------------------------------------
# DataFrame tienda4
# Producto                          object
# Categoría del Producto            object
# Precio                           float64
# Costo de envío                   float64
# Fecha de Compra           datetime64[ns]
# Vendedor                          object
# Lugar de Compra                   object
# Calificación                       int64
# Método de pago                    object
# Cantidad de cuotas                 int64
# lat                              float64
# lon                              float64
# dtype: object
# ----------------------------------------

# %% [markdown]
# #1. Análisis de facturación

# %%
ingresos_tiendas = pd.DataFrame({'Tiendas': ['Tienda1', 'Tienda2', 'Tienda3', 'Tienda4'],
                                 'Ingresos Totales': [sum(tienda1['Precio']),sum(tienda2['Precio']),
                                                      sum(tienda3['Precio']),sum(tienda4['Precio'])]})
ingresos_tiendas['Ingresos Totales'] = ingresos_tiendas['Ingresos Totales'].astype(int)
ingresos_tiendas
# Out:
#    Tiendas  Ingresos Totales
# 0  Tienda1        1150880400
# 1  Tienda2        1116343500
# 2  Tienda3        1098019600
# 3  Tienda4        1038375700

# %% [markdown]
# # 2. Ventas por categoría

# %%
tienda1['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
tienda2['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
tienda3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
tienda4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
resultados =[]
for i, x in enumerate([tienda1,tienda2,tienda3,tienda4], start=1):
  top5 =x['Categoría del Producto'].value_counts()
  for categoria, cantidad in top5.items():
    resultados.append({'Tienda': f'Tienda{i}',
                       'Categoria': categoria,
                       'Cantidad Vendida': cantidad})
Ventas_por_categoria = pd.DataFrame(resultados)
Ventas_por_categoria
# Out:
#      Tienda                Categoria  Cantidad Vendida
# 0   Tienda1                  Muebles               465
# 1   Tienda1             Electrónicos               448
# 2   Tienda1                 Juguetes               324
# 3   Tienda1        Electrodomésticos               312
# 4   Tienda1     Deportes y diversión               284
# 5   Tienda1   Instrumentos musicales               182
# 6   Tienda1                   Libros               173
# 7   Tienda1  Artículos para el hogar               171
# 8   Tienda2                  Muebles               442
# 9   Tienda2             Electrónicos               422
# 10  Tienda2                 Juguetes               313
# 11  Tienda2        Electrodomésticos               305
# 12  Tienda2     Deportes y diversión               275
# 13  Tienda2   Instrumentos musicales               224
# 14  Tienda2                   Libros               197
# 15  Tienda2  Artículos para el hogar               181
# 16  Tienda3                  Muebles               499
# 17  Tienda3             Electrónicos               451
# 18  Tienda3                 Juguetes               315
# 19  Tienda3        Electrodomésticos               278
# 20  Tienda3     Deportes y diversión               277
# 21  Tienda3                   Libros               185
# 22  Tienda3   Instrumentos musicales               177
# 23  Tienda3  Artículos para el hogar               177
# 24  Tienda4                  Muebles               480
# 25  Tienda4             Electrónicos               451
# 26  Tienda4                 Juguetes               338
# 27  Tienda4     Deportes y diversión               277
# 28  Tienda4        Electrodomésticos               254
# 29  Tienda4  Artículos para el hogar               201
# 30  Tienda4                   Libros               187
# 31  Tienda4   Instrumentos musicales               170

# %%
suma_por_categoria = Ventas_por_categoria.groupby('Categoria')['Cantidad Vendida'].sum().sort_values()
suma_por_categoria
# Out:
# Categoria
# Artículos para el hogar     730
# Libros                      742
# Instrumentos musicales      753
# Deportes y diversión       1113
# Electrodomésticos          1149
# Juguetes                   1290
# Electrónicos               1772
# Muebles                    1886
# Name: Cantidad Vendida, dtype: int64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
'''for i, x in enumerate([tienda1, tienda2, tienda3, tienda4], start=1):
  print(f"Calificación promedio de la Tienda{i}:")
  print(round(x['Calificación'].mean(), 2))
  print("-" * 33)'''
# Out:
# 'for i, x in enumerate([tienda1, tienda2, tienda3, tienda4], start=1):\n  print(f"Calificación promedio de la Tienda{i}:")\n  print(round(x[\'Calificación\'].mean(), 2))\n  print("-" * 33)'

# %%
promedios = pd.DataFrame({'Tienda': ['Tienda1', 'Tienda2', 'Tienda3', 'Tienda4'],
                          'Calificación promedio':
                          [round(tienda1['Calificación'].mean(), 2), round(tienda2['Calificación'].mean(), 2),
                           round(tienda3['Calificación'].mean(), 2), round(tienda4['Calificación'].mean(), 2)]})

# %%
promedios
# Out:
#     Tienda  Calificación promedio
# 0  Tienda1                   3.98
# 1  Tienda2                   4.04
# 2  Tienda3                   4.05
# 3  Tienda4                   4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
#Los top 5 mas vendido por tienda
df_resultados_top5 =[]
for i, x in enumerate([tienda1,tienda2,tienda3,tienda4], start=1):
  top5 =x['Producto'].value_counts().head(5)
  for producto, cantidad in top5.items():
    df_resultados_top5.append({'Tienda': f'Tienda{i}',
                       'Producto': producto,
                       'Cantidad Vendida': cantidad})
Ventas_por_producto_top5 = pd.DataFrame(df_resultados_top5)
Ventas_por_producto_top5
# Out:
#      Tienda                   Producto  Cantidad Vendida
# 0   Tienda1                 Microondas                60
# 1   Tienda1              TV LED UHD 4K                60
# 2   Tienda1                    Armario                60
# 3   Tienda1           Secadora de ropa                58
# 4   Tienda1              Mesa de noche                56
# 5   Tienda2  Iniciando en programación                65
# 6   Tienda2                 Microondas                62
# 7   Tienda2                    Batería                61
# 8   Tienda2          Guitarra acústica                58
# 9   Tienda2                  Pandereta                58
# 10  Tienda3              Kit de bancas                57
# 11  Tienda3            Mesa de comedor                56
# 12  Tienda3                  Cama king                56
# 13  Tienda3               Set de ollas                55
# 14  Tienda3              Mesa de noche                55
# 15  Tienda4                   Cama box                62
# 16  Tienda4                 Cubertería                59
# 17  Tienda4    Dashboards con Power BI                56
# 18  Tienda4                  Cama king                56
# 19  Tienda4  Carrito de control remoto                55

# %%
# se genera este codigo graficar y tener el mas vendido por cada tienda
df_resultados =[]
for i, x in enumerate([tienda1,tienda2,tienda3,tienda4], start=1):
  top5 =x['Producto'].value_counts().head(1)
  for producto, cantidad in top5.items():
    df_resultados.append({'Tienda': f'Tienda{i}',
                       'Producto': producto,
                       'Cantidad Vendida': cantidad})
Ventas_por_producto = pd.DataFrame(df_resultados)
Ventas_por_producto
# Out:
#     Tienda                   Producto  Cantidad Vendida
# 0  Tienda1                 Microondas                60
# 1  Tienda2  Iniciando en programación                65
# 2  Tienda3              Kit de bancas                57
# 3  Tienda4                   Cama box                62

# %%
# Bottom 5 menos vendidos por tienda
df_resultados1_bottom5 =[]
for i, x in enumerate([tienda1,tienda2,tienda3,tienda4], start=1):
  bottom =x['Producto'].value_counts().tail(5)
  for producto, cantidad in bottom.items():
    df_resultados1_bottom5.append({'Tienda': f'Tienda{i}',
                       'Producto': producto,
                       'Cantidad Vendida': cantidad})
menos_ventas_por_producto_bottom5 = pd.DataFrame(df_resultados1_bottom5)
menos_ventas_por_producto_bottom5
# Out:
#      Tienda                     Producto  Cantidad Vendida
# 0   Tienda1  Ciencia de datos con Python                39
# 1   Tienda1                    Pandereta                36
# 2   Tienda1              Olla de presión                35
# 3   Tienda1    Auriculares con micrófono                33
# 4   Tienda1                 Celular ABXY                33
# 5   Tienda2                  Auriculares                37
# 6   Tienda2                       Sillón                35
# 7   Tienda2              Mesa de comedor                34
# 8   Tienda2                    Impresora                34
# 9   Tienda2                Juego de mesa                32
# 10  Tienda3           Guitarra eléctrica                38
# 11  Tienda3                 Set de vasos                36
# 12  Tienda3                      Mochila                36
# 13  Tienda3                   Microondas                36
# 14  Tienda3      Bloques de construcción                35
# 15  Tienda4                 Refrigerador                38
# 16  Tienda4  Ciencia de datos con Python                38
# 17  Tienda4            Guitarra acústica                37
# 18  Tienda4                      Armario                34
# 19  Tienda4           Guitarra eléctrica                33

# %%
## se genera este codigo graficar y tener el menos vendido por cada tienda
df_resultados1 =[]
for i, x in enumerate([tienda1,tienda2,tienda3,tienda4], start=1):
  bottom =x['Producto'].value_counts().tail(1)
  for producto, cantidad in bottom.items():
    df_resultados1.append({'Tienda': f'Tienda{i}',
                       'Producto': producto,
                       'Cantidad Vendida': cantidad})
menos_ventas_por_producto = pd.DataFrame(df_resultados1)
menos_ventas_por_producto
# Out:
#     Tienda                 Producto  Cantidad Vendida
# 0  Tienda1             Celular ABXY                33
# 1  Tienda2            Juego de mesa                32
# 2  Tienda3  Bloques de construcción                35
# 3  Tienda4       Guitarra eléctrica                33

# %%
import numpy as np

Ventas_por_producto['Tipo'] = 'Más vendido'
menos_ventas_por_producto['Tipo'] = 'Menos vendido'

comparacion_ventas = pd.concat([Ventas_por_producto, menos_ventas_por_producto])# unimos ambos
comparacion_ventas
# Out:
#     Tienda                   Producto  Cantidad Vendida           Tipo
# 0  Tienda1                 Microondas                60    Más vendido
# 1  Tienda2  Iniciando en programación                65    Más vendido
# 2  Tienda3              Kit de bancas                57    Más vendido
# 3  Tienda4                   Cama box                62    Más vendido
# 0  Tienda1               Celular ABXY                33  Menos vendido
# 1  Tienda2              Juego de mesa                32  Menos vendido
# 2  Tienda3    Bloques de construcción                35  Menos vendido
# 3  Tienda4         Guitarra eléctrica                33  Menos vendido

# %%
import matplotlib.pyplot as plt

# Suponiendo que ya tienes el DataFrame 'comparacion_ventas'
tiendas = comparacion_ventas['Tienda'].unique()
tipos = comparacion_ventas['Tipo'].unique()
x = np.arange(len(tiendas))

width = 0.35  # ancho de barra
plt.figure(figsize=(10,6))

colores = ['#bddf26', '#29af7f']  # color para cada tipo

for i, tipo in enumerate(tipos):
    subset = comparacion_ventas[comparacion_ventas['Tipo'] == tipo]
    plt.bar(x + i*width, subset['Cantidad Vendida'], width=width, label=tipo, color=colores[i])

    # Etiquetas de producto encima de cada barra
    for j, v in enumerate(subset['Cantidad Vendida']):
        producto = subset.iloc[j]['Producto']
        plt.text(
            x[j] + i*width, v + 1, producto,
            ha='center', rotation=20, fontsize=8,  # rotación leve
            rotation_mode='anchor'
        )

plt.title('Producto Más y Menos Vendido por Tienda', pad=25)  # separa el título del gráfico
plt.xlabel('Tienda')
plt.ylabel('Cantidad Vendida')
plt.xticks(x + width/2, tiendas)
plt.legend(title='Tipo de producto')

plt.subplots_adjust(top=0.88)  #  da más espacio arriba
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
promedios_envios = pd.DataFrame({'Tienda': ['Tienda1', 'Tienda2', 'Tienda3', 'Tienda4'],
                          'Envío promedio':
                          [round(tienda1['Costo de envío'].mean(), 2), round(tienda2['Costo de envío'].mean(), 2),
                           round(tienda3['Costo de envío'].mean(), 2), round(tienda4['Costo de envío'].mean(), 2)]})
promedios_envios
# Out:
#     Tienda  Envío promedio
# 0  Tienda1        26018.61
# 1  Tienda2        25216.24
# 2  Tienda3        24805.68
# 3  Tienda4        23459.46

# %% [markdown]
# # Informe final

# %% [markdown]
# Este projecto se realizo con el objetivo de identificar cual de las cuatro tiendas de AluraStore presenta el menor rendimiento general, con el fin de recomendar al Sr. Juan que tienda deberia vender para iniciar el nuevo emprendimiento.
#
# Para ello, se analizaron indicadores clave de desempeño como los ingresos totales, las categorias y productos mas vendidos, las calificaciones promedios de los clientes y el coste de envios promedio por tienda. Tambien se generaron graficos para visualizar y comparar el comportamiento de cada tienda. La decisión se basa en un análisis integral que combina métricas de ventas, satisfacción del cliente y costos para recomendar la opción que ofrezca el mayor potencial de éxito.

# %% [markdown]
# ## Ingresos totales por tienda
#
#    El analisis de ingresos muestra que la Tienda1 obtuvo los mayores ingresos totales, seguida por la Tienda2. Las Tiendas3 y Tienda4 presentan ingresos menores. Esto indica que, en términos de facturación bruta, Tienda1 tiene el mayor potencial de ventas. Sin embargo, la diferencia con Tienda2 no es demasiado amplia, lo que sugiere que otras variables podrían influir en la decisión final.

# %%
plt.figure(figsize=(8,5))
plt.bar(ingresos_tiendas['Tiendas'], ingresos_tiendas['Ingresos Totales'].astype(float), color='#482173')
plt.title('Ingresos Totales por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Ingresos ($)')
# Etiquetas encima de cada barra
for i, v in enumerate(ingresos_tiendas['Ingresos Totales']):
    #plt.text(i, v + max(ingresos_tiendas['Ingresos Totales'])*0.01, str(v), ha='center', fontsize=9, fontweight='bold')
    plt.text(i, v + max(ingresos_tiendas['Ingresos Totales'])*0.01, f"${v:,.2f}", ha='center', fontweight='bold', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Categorias más y menos vendidas por tienda

# %% [markdown]
# Las categorías de productos con mayor demanda son **Muebles y Electrónicos**, mientras que las menos vendidas incluyen **Artículos para el hogar, Libros e Instrumentos musicales**. Tienda3 destaca especialmente en Muebles, lo que podría atraer clientes interesados en esta categoría. Tienda1 mantiene un desempeño sólido en casi todas las categorías principales, mostrando un equilibrio general en la oferta de productos.

# %%
import seaborn as sns

plt.figure(figsize=(8,6))
sns.barplot(data=Ventas_por_categoria, x= 'Tienda', y='Cantidad Vendida', hue= 'Categoria',palette='viridis')

plt.title('Categorías de produtos Más Vendidas por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Cantidad Vendida')
plt.xticks(rotation=45)
plt.legend(title= 'Categorias')

# %% [markdown]
# ## Valoración media por tienda

# %% [markdown]
# La calificación promedio de los clientes es un indicador de satisfacción y fidelización. Tienda3 obtiene la mayor calificación con 4.05, seguida de Tienda2 con 4.04. Tienda1, aunque líder en ingresos, presenta la calificación más baja (3.98), lo que puede reflejar problemas de experiencia del cliente o servicio.

# %%
# Ordenar de mayor a menor
promedios_ordenado = promedios.sort_values(by='Calificación promedio', ascending=False)

# Gráfico horizontal
plt.figure(figsize=(8,5))
plt.barh(promedios_ordenado['Tienda'], promedios_ordenado['Calificación promedio'], color='#29af7f')
plt.xlabel('Calificación Promedio')
plt.ylabel('Tienda')
plt.xlim(0,5)

# Etiquetas encima de cada barra
for i, v in enumerate(promedios_ordenado['Calificación promedio']):
    plt.text(v + 0.05, i, str(v), va='center', fontweight='bold')

plt.title('Calificación Promedio por Tienda (Mayor a Menor)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Valor del envío promedio por tienda

# %% [markdown]
# El coste de envío puede influir directamente en la decisión de compra de los clientes. Tienda1 tiene el envío promedio más alto, lo que podría desincentivar compras, mientras que Tienda4 ofrece el envío más bajo. Tienda2 y Tienda3 se encuentran en un rango competitivo y razonable, lo que contribuye a una experiencia de compra más atractiva para los clientes sin comprometer la rentabilidad.

# %%
plt.plot(promedios_envios['Tienda'], promedios_envios['Envío promedio'], marker = 'o', color='#2e6f8e')
plt.title('Costo de Envío Promedio por Tienda')
plt.ylabel('Envío Promedio')
plt.xlabel('Tiendas')
plt.ylim(0, max(promedios_envios['Envío promedio'])+25000)
# Etiquetas de valor
for i, v in enumerate(promedios_envios['Envío promedio']):
    plt.text(i, v + 200, f"${v:,.2f}", ha='center', fontweight='bold', fontsize=8)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusión

# %% [markdown]
# Del análisis realizado se observa que **Tienda1** destaca por sus altos ingresos, pero presenta debilidades en la satisfacción del cliente y en sus elevados costes de envío. **Tienda2 ** muestra un equilibrio ideal entre ingresos, satisfacción del cliente y costes competitivos, posicionándose como la tienda más eficiente. **Tienda3** ofrece la mejor valoración por parte de los clientes, aunque sus ingresos son ligeramente menores. En contraste, **Tienda4** tiene el coste de envío más bajo, pero también los ingresos y calificaciones más bajas del grupo.
#
# **En conclusión**, se determina que la **Tienda4**es la menos eficiente dentro de la cadena AluraStore, ya que su bajo desempeño en ventas y satisfacción del cliente no compensa su menor coste de envío. Por ello, se recomienda que el **Sr. Juan** venda la **Tienda4** para enfocar sus recursos en las tiendas con mejor rendimiento, especialmente Tienda2 y Tienda3, optimizando así la rentabilidad y el crecimiento de su nuevo emprendimiento.

# %% [markdown]
# # Análisis del desempeño geográfico

# %% [markdown]
# - Zonas de mayor densidad de ventas

# %%
import folium
from folium.plugins import HeatMap

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy) (2.1)

# %%
from geopy.geocoders import Nominatim

# %%
import time

# %%
import os

# %%
geolocalizador = Nominatim(user_agent='ventas_geolocalizacion') # Inicializar geolocalizador y caché global

# %%
cache_regiones = {}  # caché global para coordenadas consultadas

# %%
# función para crear el mapa por tienda
def crear_mapa_por_tienda(tienda, nombre_archivo):
  """
    Crea un mapa interactivo con marcadores y un mapa de calor basado en los datos de una tienda.
    """
  mapa = folium.Map(location=[tienda['lat'].mean(), tienda['lon'].mean()], zoom_start = 6) # se crea un mapa base con folium de ubicación promedio de las tiendas

  # creamos una lista - mapa de calor con lat,lon, precio por cada fila del datafrmae
  mapa_de_calor = [[row['lat'], row['lon'], row['Precio']] for index, row in tienda.iterrows()] # iterrows() permite iterar cada fila en el dataframe

  # Esta lista mapa_de_calor alimenta al HeatMap, donde el “peso” (Precio) determina la intensidad del color.
  HeatMap(mapa_de_calor, radius=10, blur=15, max_zoom=1).add_to(mapa) # donde se concentran los precios de los productos.

  # Crea un marcador individual en la ubicación (lat, lon) de la tienda o producto.
  for i, row in tienda.iterrows():
    folium.Marker(location = [row['lat'], row['lon']],
                  popup = f"Producto:{row['Producto']}<br>" # Al hacer clic sobre el marcador, aparece un popup con la información
                            f"Categoria:{row['Categoría del Producto']}<br>"
                        f"Precio: ${row['Precio']:.2f}").add_to(mapa)

  # Guardar el mapa en un archivo HTML
  os.makedirs("docs", exist_ok=True)
  mapa.save(nombre_archivo)
  print(f"Mapa guardado en: {nombre_archivo}")

  return mapa

# %%
crear_mapa_por_tienda(tienda1, 'docs/mapa_tienda1.html')
# Out:
# Mapa guardado en: docs/mapa_tienda1.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf51aa8407d4bca836d949af7dcbd649 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf51aa8407d4bca836d949af7dcbd649&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf51aa8407d4bca836d949af7dcbd649 = L.map(
#                 &quot;map_bf51aa8407d4bca836d949af7dcbd649&quot;,
#                 {
#                     center: [5.365282831708351, -74.7894174014413],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83915e0c43972c669c928df4ccb17bb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83915e0c43972c669c928df4ccb17bb7.addTo(map_bf51aa8407d4bca836d949af7dcbd649);
#
#
#             var heat_map_70d48b5968b43928f98ddd91bcb5edbb = L.heatLayer(
#                 [[4.60971, -74.08175, 164300.0], [6.25184, -75.56359, 192300.0], [10.39972, -75.51444, 209600.0], [3.43722, -76.5225, 757500.0], [6.25184, -75.56359, 335200.0], [3.43722, -76.5225, 24200.0], [4.60971, -74.08175, 44200.0], [11.24079, -74.19904, 1189700.0], [4.60971, -74.08175, 1518200.0], [4.60971, -74.08175, 75200.0], [4.60971, -74.08175, 2431300.0], [10.39972, -75.51444, 1417100.0], [6.25184, -75.56359, 91800.0], [4.81333, -75.69611, 66700.0], [4.60971, -74.08175, 613300.0], [3.43722, -76.5225, 56900.0], [6.25184, -75.56359, 58900.0], [11.24079, -74.19904, 29600.0], [4.60971, -74.08175, 1891700.0], [6.25184, -75.56359, 138900.0], [3.43722, -76.5225, 435700.0], [4.60971, -74.08175, 50800.0], [6.25184, -75.56359, 514500.0], [4.60971, -74.08175, 293500.0], [6.25184, -75.56359, 33500.0], [4.60971, -74.08175, 47900.0], [6.25184, -75.56359, 139300.0], [4.60971, -74.08175, 583900.0], [10.96854, -74.78132, 18400.0], [4.60971, -74.08175, 79100.0], [6.25184, -75.56359, 564200.0], [6.25184, -75.56359, 153900.0], [6.25184, -75.56359, 331400.0], [4.60971, -74.08175, 55600.0], [4.60971, -74.08175, 24700.0], [6.25184, -75.56359, 62300.0], [4.60971, -74.08175, 300200.0], [3.43722, -76.5225, 305400.0], [4.60971, -74.08175, 30500.0], [4.142, -73.62664, 327200.0], [3.43722, -76.5225, 68300.0], [3.43722, -76.5225, 513400.0], [6.25184, -75.56359, 13900.0], [4.60971, -74.08175, 362000.0], [4.60971, -74.08175, 240300.0], [6.25184, -75.56359, 428300.0], [3.8653, -67.9239, 679000.0], [6.25184, -75.56359, 100900.0], [3.43722, -76.5225, 739700.0], [7.89391, -72.50782, 630000.0], [3.43722, -76.5225, 1130300.0], [6.25184, -75.56359, 318900.0], [4.60971, -74.08175, 297000.0], [3.43722, -76.5225, 402200.0], [6.25184, -75.56359, 17100.0], [4.60971, -74.08175, 38700.0], [7.89391, -72.50782, 605800.0], [4.60971, -74.08175, 1122700.0], [4.60971, -74.08175, 125900.0], [6.25184, -75.56359, 18300.0], [5.06889, -75.51738, 12800.0], [4.60971, -74.08175, 423500.0], [6.25184, -75.56359, 315200.0], [4.60971, -74.08175, 74100.0], [4.60971, -74.08175, 293800.0], [6.25184, -75.56359, 2525400.0], [6.25184, -75.56359, 1200300.0], [3.43722, -76.5225, 53000.0], [2.9273, -75.28189, 250100.0], [4.60971, -74.08175, 680900.0], [4.60971, -74.08175, 111000.0], [6.25184, -75.56359, 1196000.0], [7.12539, -73.1198, 45100.0], [3.43722, -76.5225, 284200.0], [4.60971, -74.08175, 490400.0], [4.60971, -74.08175, 143600.0], [10.46314, -73.25322, 139100.0], [6.25184, -75.56359, 84600.0], [6.25184, -75.56359, 401900.0], [4.60971, -74.08175, 2172400.0], [10.96854, -74.78132, 296400.0], [4.60971, -74.08175, 368700.0], [6.25184, -75.56359, 130800.0], [6.25184, -75.56359, 1396500.0], [10.39972, -75.51444, 42100.0], [1.21361, -77.28111, 44800.0], [4.60971, -74.08175, 35300.0], [6.25184, -75.56359, 444800.0], [4.60971, -74.08175, 412500.0], [4.60971, -74.08175, 59800.0], [3.43722, -76.5225, 42000.0], [4.60971, -74.08175, 288300.0], [4.60971, -74.08175, 434600.0], [10.46314, -73.25322, 245600.0], [6.25184, -75.56359, 53800.0], [7.89391, -72.50782, 722600.0], [3.43722, -76.5225, 78300.0], [4.60971, -74.08175, 279300.0], [6.25184, -75.56359, 475100.0], [6.25184, -75.56359, 72600.0], [4.60971, -74.08175, 49400.0], [6.25184, -75.56359, 22800.0], [4.60971, -74.08175, 54600.0], [4.60971, -74.08175, 33500.0], [4.60971, -74.08175, 701900.0], [6.25184, -75.56359, 1438900.0], [4.60971, -74.08175, 55300.0], [11.54444, -72.90722, 53200.0], [4.60971, -74.08175, 222500.0], [4.60971, -74.08175, 535900.0], [4.60971, -74.08175, 172300.0], [4.60971, -74.08175, 39700.0], [4.60971, -74.08175, 66900.0], [4.60971, -74.08175, 2761500.0], [4.60971, -74.08

# %%
# funcion para obtener la region y llamarla despues
def obtener_region(lat, lon, usar_cache=True):
  """ Obtiene la región (ciudad, estado o país) a partir de coordenadas (lat, lon),
    usando una caché para evitar consultas repetidas al geolocalizador.
    """
  clave = (round(lat, 3), round(lon, 3))  # clave redondeada para evitar duplicados minimos

   # Si ya está en caché, se devuelve inmediatamente
  if usar_cache and clave in cache_regiones:
    return cache_regiones[clave]
  try:
    localizacion = geolocalizador.reverse((lat,lon), language='es')
    if localizacion and 'address' in localizacion.raw:
      direccion = localizacion.raw['address']
      region = direccion.get('city', direccion.get('state', direccion.get('country', 'Desconocido')))
    else:
      return 'Desconocido'
  except Exception as e:
        return f'Error: {e}'
  # Guardamos resultado en caché
  if usar_cache:
    cache_regiones[clave] = region

  return region

# %%
# Función para analizar zonas y obtener top ventas
def analizar_zona_tienda(tienda, obtener_region, top_n, esperar=True, delay=1, usar_cache=True ):
  """
    Agrupa las ventas por coordenadas aproximadas, obtiene la región y devuelve las zonas con más ventas.
    Usa caché para evitar consultas repetidas al geolocalizador.
    """
  tienda['Latitud Aproximada'] = tienda['lat'].round(1) # Redondeamos coordenadas para agrupar por "zona"
  tienda['Longitud Aproximada'] = tienda['lon'].round(1)
  zonas = tienda.groupby(['Latitud Aproximada', 'Longitud Aproximada']).agg({'Precio': 'sum'}).reset_index()

  # Obtener regiones
  regiones = []
  for _, row in zonas.iterrows():
    region = obtener_region(row['Latitud Aproximada'],row['Longitud Aproximada'],usar_cache = usar_cache)
    regiones.append(region)
    if esperar:
      time.sleep(delay)

  zonas['Region'] = regiones

  zonas_mayor_ventas = zonas.sort_values('Precio', ascending=False).head(top_n)

  print(f"Se analizaron {len(zonas)} zonas. Mostrando las {top_n} con mayores ventas.")
  print(f"Caché actual: {len(cache_regiones)} coordenadas guardadas.")

  return zonas_mayor_ventas

# %%
# función para crear el mapa para usarla con la funcion analizar_y_mapear_tienda()
def crear_mapa_por_tienda_top_n(tienda, nombre_archivo):
  """
    Crea un mapa interactivo con marcadores y un mapa de calor basado en los datos de una tienda.
    """
  mapa = folium.Map(location=[tienda['Latitud Aproximada'].mean(), tienda['Longitud Aproximada'].mean()], zoom_start = 6) # se crea un mapa base con folium de ubicación promedio de las tiendas

  # creamos una lista - mapa de calor con lat,lon, precio por cada fila del datafrmae
  mapa_de_calor = [[row['Latitud Aproximada'], row['Longitud Aproximada'], row['Precio']] for index, row in tienda.iterrows()] # iterrows() permite iterar cada fila en el dataframe

  # Esta lista mapa_de_calor alimenta al HeatMap, donde el “peso” (Precio) determina la intensidad del color.
  HeatMap(mapa_de_calor, radius=10, blur=15, max_zoom=1).add_to(mapa) # donde se concentran los precios de los productos.

  # Crea un marcador individual en la ubicación (lat, lon) de la tienda o producto.
  for i, row in tienda.iterrows():
    folium.Marker(location = [row['Latitud Aproximada'], row['Longitud Aproximada']],
                  popup = f"Precio: ${row['Precio']:.2f}").add_to(mapa)  # Al hacer clic sobre el marcador, aparece un popup con la información

  # Guardar el mapa en un archivo HTML
  mapa.save(nombre_archivo)
  print(f"Mapa guardado en: {nombre_archivo}")

  return mapa

# %%
def analizar_y_mapear_tienda(df_tienda, nombre_archivo, top_n, esperar=False, delay=1,
                             usar_cache=True, incluir_heatmap=True):
  """
    Combina el análisis de zonas con la creación del mapa de ventas.
    Retorna el DataFrame de zonas con más ventas y genera el mapa HTML de esas zonas.
    """
  zonas_top = analizar_zona_tienda(df_tienda, obtener_region, top_n)

  mapa = crear_mapa_por_tienda_top_n(zonas_top, nombre_archivo)

  return zonas_top, mapa

# %%
zonas_top5_tienda1, mapa_top5_tienda1 = analizar_y_mapear_tienda(tienda1, 'mapa_top5_tienda1.html', 5)
mapa_top5_tienda1  # al poner solo el objeto, lo renderiza como mapa interactivo
# Out:
# Se analizaron 19 zonas. Mostrando las 5 con mayores ventas.
# Caché actual: 19 coordenadas guardadas.
# Mapa guardado en: mapa_top5_tienda1.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8be9c0acdbd4a0b229fac5f72f150e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8be9c0acdbd4a0b229fac5f72f150e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8be9c0acdbd4a0b229fac5f72f150e9 = L.map(
#                 &quot;map_c8be9c0acdbd4a0b229fac5f72f150e9&quot;,
#                 {
#                     center: [5.4, -74.88],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40fdb432e8e19d19d6f0231ef23c1014 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40fdb432e8e19d19d6f0231ef23c1014.addTo(map_c8be9c0acdbd4a0b229fac5f72f150e9);
#
#
#             var heat_map_e476947c0afb39884c6a5366e94b376c = L.heatLayer(
#                 [[4.6, -74.1, 440005000.0], [6.3, -75.6, 296858100.0], [3.4, -76.5, 154493700.0], [4.8, -75.7, 56214300.0], [7.9, -72.5, 37879500.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 10,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_e476947c0afb39884c6a5366e94b376c.addTo(map_c8be9c0acdbd4a0b229fac5f72f150e9);
#
#
#             var marker_b97651c918f83ef48b4eac5d98098501 = L.marker(
#                 [4.6, -74.1],
#                 {
# }
#             ).addTo(map_c8be9c0acdbd4a0b229fac5f72f150e9);
#
#
#         var popup_981a2b4943fcacd0ce3d46b2f034618e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3de0845f256b9ab842e1b53f0be011 = $(`&lt;div id=&quot;html_7f3de0845f256b9ab842e1b53f0be011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $440005000.00&lt;/div&gt;`)[0];
#                 popup_981a2b4943fcacd0ce3d46b2f034618e.setContent(html_7f3de0845f256b9ab842e1b53f0be011);
#
#
#
#         marker_b97651c918f83ef48b4eac5d98098501.bindPopup(popup_981a2b4943fcacd0ce3d46b2f034618e)
#         ;
#
#
#
#
#             var marker_c8fda063985fa920ad6cb95f9d154054 = L.marker(
#                 [6.3, -75.6],
#                 {
# }
#             ).addTo(map_c8be9c0acdbd4a0b229fac5f72f150e9);
#
#
#         var popup_1e9a70de21452e2ded1aca9c16090dbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c0000e46cfdfb68057c7e5e4467973 = $(`&lt;div id=&quot;html_50c0000e46cfdfb68057c7e5e4467973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $296858100.00&lt;/div&gt;`)[0];
#                 popup_1e9a70de21452e2ded1aca9c16090dbd.setContent(html_50c0000e46cfdfb68057c7e5e4467973);
#
#
#
#         marker_c8fda063985fa920ad6cb95f9d154054.bindPopup(popup_1e9a70de21452e2ded1aca9c16090dbd)
#         ;
#
#
#
#
#             var marker_2d5303667d51a1985e2446bda5ce67ae = L.marker(
#                 [3.4, -76.5],
#                 {
# }
#             ).addTo(map_c8be9c0acdbd4a0b229fac5f72f150e9);
#
#
#         var popup_e8ab500877e9da49b05422aac98436d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03ace96cd1b7f50212d58a0d09325e72 = $(`&lt;div id=&quot;html_03ace96cd1b7f50212d58a0d09325e72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $154493700.00&lt;/div&gt;`)[0];
#                 popup_e8ab500877e9da49b05422aac98436d4.setContent(html_03ace96cd1b7f50212d58a0d09325e72);
#
#
#
#         marker_2d5303667d51a1985e2446bda5ce67ae.bindPopup(popup_e8ab500877e9da49b05422aac98436d4)
#         ;
#
#
#
#
#             var marker_cf2b262dfcb7bdec43ca5eca7db09aa0 = L.marker(
#                 [4.8, -75.7],
#                 {
# }
#             ).addTo(map_c8be9c0acdbd4a0b229fac5f72f150e9);
#
#
#         var popup_d32b946bb645a101acf70f012979deda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b984faee4eb291043da88ffc42a6af25 = $(`&lt;div id=&quot;html_b984faee4eb291043da88ffc42a6af25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $56214300.00&lt;/div&gt;`)[0];
#                 popup_d32b946bb645a101acf70f012979deda.setContent(html_b984faee4eb291043da88ffc42a6af25);
#
#
#
#         marker_cf2b262dfcb7bdec43ca5eca7db09aa0.bindPopup(popup_d32b946bb645a101acf70f012979deda)
#         ;
#
#
#
#
#             var marker_ff05e9155dbdb77bb5a63586430a75af = L.mark

# %%
zonas_top5_tienda2, mapa_top5_tienda2 = analizar_y_mapear_tienda(tienda2, 'mapa_top5_tienda2.html', 5)
mapa_top5_tienda2  # al poner solo el objeto, Jupyter lo renderiza como mapa interactivo
# Out:
# Se analizaron 19 zonas. Mostrando las 5 con mayores ventas.
# Caché actual: 19 coordenadas guardadas.
# Mapa guardado en: mapa_top5_tienda2.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3e49395fb526cb4423bcc0fb4d6d67b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3e49395fb526cb4423bcc0fb4d6d67b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3e49395fb526cb4423bcc0fb4d6d67b = L.map(
#                 &quot;map_b3e49395fb526cb4423bcc0fb4d6d67b&quot;,
#                 {
#                     center: [5.4, -74.88],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd525ae6e9b206913a22b8be1765c53 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afd525ae6e9b206913a22b8be1765c53.addTo(map_b3e49395fb526cb4423bcc0fb4d6d67b);
#
#
#             var heat_map_83a2e6c459b92e53d65eeb67500482ca = L.heatLayer(
#                 [[4.6, -74.1, 479959200.0], [6.3, -75.6, 297246700.0], [3.4, -76.5, 118257600.0], [4.8, -75.7, 43073800.0], [7.9, -72.5, 28991500.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 10,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_83a2e6c459b92e53d65eeb67500482ca.addTo(map_b3e49395fb526cb4423bcc0fb4d6d67b);
#
#
#             var marker_e3cc109bdb29b3cb2994da3e687216b7 = L.marker(
#                 [4.6, -74.1],
#                 {
# }
#             ).addTo(map_b3e49395fb526cb4423bcc0fb4d6d67b);
#
#
#         var popup_eb80d7c8ba6eff70529c91fa9a799108 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8af531f7e75d60353a56140379594a95 = $(`&lt;div id=&quot;html_8af531f7e75d60353a56140379594a95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $479959200.00&lt;/div&gt;`)[0];
#                 popup_eb80d7c8ba6eff70529c91fa9a799108.setContent(html_8af531f7e75d60353a56140379594a95);
#
#
#
#         marker_e3cc109bdb29b3cb2994da3e687216b7.bindPopup(popup_eb80d7c8ba6eff70529c91fa9a799108)
#         ;
#
#
#
#
#             var marker_a16736ccaa052873c5872eb32fb934c3 = L.marker(
#                 [6.3, -75.6],
#                 {
# }
#             ).addTo(map_b3e49395fb526cb4423bcc0fb4d6d67b);
#
#
#         var popup_dd7e4f97dd8da97a1ab7a7e904268990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79bfa550373597c14120e8fc94c85988 = $(`&lt;div id=&quot;html_79bfa550373597c14120e8fc94c85988&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $297246700.00&lt;/div&gt;`)[0];
#                 popup_dd7e4f97dd8da97a1ab7a7e904268990.setContent(html_79bfa550373597c14120e8fc94c85988);
#
#
#
#         marker_a16736ccaa052873c5872eb32fb934c3.bindPopup(popup_dd7e4f97dd8da97a1ab7a7e904268990)
#         ;
#
#
#
#
#             var marker_774fcc33b8585c8df9c4bad3ed711ccb = L.marker(
#                 [3.4, -76.5],
#                 {
# }
#             ).addTo(map_b3e49395fb526cb4423bcc0fb4d6d67b);
#
#
#         var popup_578180fb25468565649d95b809f672f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e8378eaf6e8bbee07cdd7056611a33c = $(`&lt;div id=&quot;html_2e8378eaf6e8bbee07cdd7056611a33c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $118257600.00&lt;/div&gt;`)[0];
#                 popup_578180fb25468565649d95b809f672f0.setContent(html_2e8378eaf6e8bbee07cdd7056611a33c);
#
#
#
#         marker_774fcc33b8585c8df9c4bad3ed711ccb.bindPopup(popup_578180fb25468565649d95b809f672f0)
#         ;
#
#
#
#
#             var marker_60cd9cf8dfcc2ffb6f07f7969487a202 = L.marker(
#                 [4.8, -75.7],
#                 {
# }
#             ).addTo(map_b3e49395fb526cb4423bcc0fb4d6d67b);
#
#
#         var popup_114e1fbf00154381dc63bc55ec59d087 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8b051d1ca5a6b67b79e9422a6e9ef05 = $(`&lt;div id=&quot;html_b8b051d1ca5a6b67b79e9422a6e9ef05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $43073800.00&lt;/div&gt;`)[0];
#                 popup_114e1fbf00154381dc63bc55ec59d087.setContent(html_b8b051d1ca5a6b67b79e9422a6e9ef05);
#
#
#
#         marker_60cd9cf8dfcc2ffb6f07f7969487a202.bindPopup(popup_114e1fbf00154381dc63bc55ec59d087)
#         ;
#
#
#
#
#             var marker_180ce9e540c403b1115e7d7ff6517503 = L.mark

# %%
zonas_top5_tienda3, mapa_top5_tienda3 = analizar_y_mapear_tienda(tienda3, 'mapa_top5_tienda3.html', 5)
mapa_top5_tienda3  # al poner solo el objeto, Jupyter lo renderiza como mapa interactivo
# Out:
# Se analizaron 19 zonas. Mostrando las 5 con mayores ventas.
# Caché actual: 19 coordenadas guardadas.
# Mapa guardado en: mapa_top5_tienda3.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e76ef8deeea4b1ef93945d4c9af18c18 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e76ef8deeea4b1ef93945d4c9af18c18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e76ef8deeea4b1ef93945d4c9af18c18 = L.map(
#                 &quot;map_e76ef8deeea4b1ef93945d4c9af18c18&quot;,
#                 {
#                     center: [6.02, -75.34],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10356e2e77bbbff94b3d161dbb314d96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10356e2e77bbbff94b3d161dbb314d96.addTo(map_e76ef8deeea4b1ef93945d4c9af18c18);
#
#
#             var heat_map_ec2e9b7932194fdf794f84ddf7e96923 = L.heatLayer(
#                 [[4.6, -74.1, 475562100.0], [6.3, -75.6, 250580600.0], [3.4, -76.5, 109287600.0], [4.8, -75.7, 62504500.0], [11.0, -74.8, 36768500.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 10,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_ec2e9b7932194fdf794f84ddf7e96923.addTo(map_e76ef8deeea4b1ef93945d4c9af18c18);
#
#
#             var marker_843d018cfc609903f81c1c233405b986 = L.marker(
#                 [4.6, -74.1],
#                 {
# }
#             ).addTo(map_e76ef8deeea4b1ef93945d4c9af18c18);
#
#
#         var popup_840fe14ce74c9437414dc51c620571ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8792bad13edc64cafe77a280cfe1638c = $(`&lt;div id=&quot;html_8792bad13edc64cafe77a280cfe1638c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $475562100.00&lt;/div&gt;`)[0];
#                 popup_840fe14ce74c9437414dc51c620571ba.setContent(html_8792bad13edc64cafe77a280cfe1638c);
#
#
#
#         marker_843d018cfc609903f81c1c233405b986.bindPopup(popup_840fe14ce74c9437414dc51c620571ba)
#         ;
#
#
#
#
#             var marker_cdf1aaf71ca0ca1833b80b2952e876dc = L.marker(
#                 [6.3, -75.6],
#                 {
# }
#             ).addTo(map_e76ef8deeea4b1ef93945d4c9af18c18);
#
#
#         var popup_150b7034cb5faf85f4a8ec53090a2d5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_787bb3939cff22496d0235cf9004a70a = $(`&lt;div id=&quot;html_787bb3939cff22496d0235cf9004a70a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $250580600.00&lt;/div&gt;`)[0];
#                 popup_150b7034cb5faf85f4a8ec53090a2d5f.setContent(html_787bb3939cff22496d0235cf9004a70a);
#
#
#
#         marker_cdf1aaf71ca0ca1833b80b2952e876dc.bindPopup(popup_150b7034cb5faf85f4a8ec53090a2d5f)
#         ;
#
#
#
#
#             var marker_127addf0aeba525c6ac74e70e764e91f = L.marker(
#                 [3.4, -76.5],
#                 {
# }
#             ).addTo(map_e76ef8deeea4b1ef93945d4c9af18c18);
#
#
#         var popup_3c7cead718aa653c4b925168093c2a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78e6e1e1057387e518034294dbebd9fe = $(`&lt;div id=&quot;html_78e6e1e1057387e518034294dbebd9fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $109287600.00&lt;/div&gt;`)[0];
#                 popup_3c7cead718aa653c4b925168093c2a32.setContent(html_78e6e1e1057387e518034294dbebd9fe);
#
#
#
#         marker_127addf0aeba525c6ac74e70e764e91f.bindPopup(popup_3c7cead718aa653c4b925168093c2a32)
#         ;
#
#
#
#
#             var marker_5c1832fa1719624ddc411e6939140672 = L.marker(
#                 [4.8, -75.7],
#                 {
# }
#             ).addTo(map_e76ef8deeea4b1ef93945d4c9af18c18);
#
#
#         var popup_c88254a2abb05cb690d574adcadba5f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7769f6ecca9dd4164756b7a56f87aaa6 = $(`&lt;div id=&quot;html_7769f6ecca9dd4164756b7a56f87aaa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $62504500.00&lt;/div&gt;`)[0];
#                 popup_c88254a2abb05cb690d574adcadba5f5.setContent(html_7769f6ecca9dd4164756b7a56f87aaa6);
#
#
#
#         marker_5c1832fa1719624ddc411e6939140672.bindPopup(popup_c88254a2abb05cb690d574adcadba5f5)
#         ;
#
#
#
#
#             var marker_1281fd23e008711e77bb23d440c79c15 = L.ma

# %%
zonas_top5_tienda4, mapa_top5_tienda4 = analizar_y_mapear_tienda(tienda4, 'mapa_top5_tienda4.html', 5)
mapa_top5_tienda4  # al poner solo el objeto, Jupyter lo renderiza como mapa interactivo
# Out:
# Se analizaron 19 zonas. Mostrando las 5 con mayores ventas.
# Caché actual: 19 coordenadas guardadas.
# Mapa guardado en: mapa_top5_tienda4.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a82f190369fa10c001a124b08ef179b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a82f190369fa10c001a124b08ef179b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a82f190369fa10c001a124b08ef179b6 = L.map(
#                 &quot;map_a82f190369fa10c001a124b08ef179b6&quot;,
#                 {
#                     center: [6.02, -75.34],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eefbe8c5cb75a72bb9bf21317bf17c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3eefbe8c5cb75a72bb9bf21317bf17c0.addTo(map_a82f190369fa10c001a124b08ef179b6);
#
#
#             var heat_map_d83df4f663636a564f571be8f48b3619 = L.heatLayer(
#                 [[4.6, -74.1, 419332000.0], [6.3, -75.6, 251983800.0], [3.4, -76.5, 124487200.0], [4.8, -75.7, 64134700.0], [11.0, -74.8, 34623000.0]],
#                 {
#   &quot;minOpacity&quot;: 0.5,
#   &quot;maxZoom&quot;: 1,
#   &quot;radius&quot;: 10,
#   &quot;blur&quot;: 15,
# }
#             );
#
#
#             heat_map_d83df4f663636a564f571be8f48b3619.addTo(map_a82f190369fa10c001a124b08ef179b6);
#
#
#             var marker_121206522fe2276d502408ff73ab7449 = L.marker(
#                 [4.6, -74.1],
#                 {
# }
#             ).addTo(map_a82f190369fa10c001a124b08ef179b6);
#
#
#         var popup_2379bea9234dee8fde9199a3615a9289 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a78b5556af7336b2781c2785d9157f = $(`&lt;div id=&quot;html_94a78b5556af7336b2781c2785d9157f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $419332000.00&lt;/div&gt;`)[0];
#                 popup_2379bea9234dee8fde9199a3615a9289.setContent(html_94a78b5556af7336b2781c2785d9157f);
#
#
#
#         marker_121206522fe2276d502408ff73ab7449.bindPopup(popup_2379bea9234dee8fde9199a3615a9289)
#         ;
#
#
#
#
#             var marker_3fe900f4db6cc5d58835a5948f214a03 = L.marker(
#                 [6.3, -75.6],
#                 {
# }
#             ).addTo(map_a82f190369fa10c001a124b08ef179b6);
#
#
#         var popup_06b34798a4658850fd860d30b7caa09d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b150a520c6d320eaccb27c6c5dc66d11 = $(`&lt;div id=&quot;html_b150a520c6d320eaccb27c6c5dc66d11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $251983800.00&lt;/div&gt;`)[0];
#                 popup_06b34798a4658850fd860d30b7caa09d.setContent(html_b150a520c6d320eaccb27c6c5dc66d11);
#
#
#
#         marker_3fe900f4db6cc5d58835a5948f214a03.bindPopup(popup_06b34798a4658850fd860d30b7caa09d)
#         ;
#
#
#
#
#             var marker_54a41765557a1e5f2928051be7884144 = L.marker(
#                 [3.4, -76.5],
#                 {
# }
#             ).addTo(map_a82f190369fa10c001a124b08ef179b6);
#
#
#         var popup_b6168599848924803c0d4c0ea04ac40a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1dd54a47bc6f8fc4b1148fe7b67ec48 = $(`&lt;div id=&quot;html_d1dd54a47bc6f8fc4b1148fe7b67ec48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $124487200.00&lt;/div&gt;`)[0];
#                 popup_b6168599848924803c0d4c0ea04ac40a.setContent(html_d1dd54a47bc6f8fc4b1148fe7b67ec48);
#
#
#
#         marker_54a41765557a1e5f2928051be7884144.bindPopup(popup_b6168599848924803c0d4c0ea04ac40a)
#         ;
#
#
#
#
#             var marker_675fde5086538db6c3a0f73da6f81a6a = L.marker(
#                 [4.8, -75.7],
#                 {
# }
#             ).addTo(map_a82f190369fa10c001a124b08ef179b6);
#
#
#         var popup_60a41616ff7132a112cd760df2e16af6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e28ecd66a96457a8f7e5e6a34a0bfa6a = $(`&lt;div id=&quot;html_e28ecd66a96457a8f7e5e6a34a0bfa6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Precio: $64134700.00&lt;/div&gt;`)[0];
#                 popup_60a41616ff7132a112cd760df2e16af6.setContent(html_e28ecd66a96457a8f7e5e6a34a0bfa6a);
#
#
#
#         marker_675fde5086538db6c3a0f73da6f81a6a.bindPopup(popup_60a41616ff7132a112cd760df2e16af6)
#         ;
#
#
#
#
#             var marker_ad5288e35f4ef1f92af6cceea398fc86 = L.ma

# %%
zonas_top5_tienda4
# Out:
#     Latitud Aproximada  Longitud Aproximada       Precio  \
# 8                  4.6                -74.1  419332000.0
# 11                 6.3                -75.6  251983800.0
# 3                  3.4                -76.5  124487200.0
# 9                  4.8                -75.7   64134700.0
# 16                11.0                -74.8   34623000.0
#
#                                        Region
# 8                                      Bogotá
# 11                                   Medellín
# 3           Perímetro Urbano Santiago de Cali
# 9   AMCO, Area Metropolitana Centro Occidente
# 16              Perímetro Urbano Barranquilla
